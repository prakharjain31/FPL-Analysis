# %%
import pyomo

# %%
import pandas as pd
from pyomo.environ import *

data = pd.read_csv('final_final.csv')
players = data['playerid'].unique()
teams = data['team_id'].unique()
gameweeks = list(range(1, 39))  
model = ConcreteModel()
model.P = Set(initialize=players)  
model.GW = Set(initialize=gameweeks)  
model.z = Var(model.P, model.GW, domain=Binary)  
cost = {row['playerid']: row['value'] for _, row in data.iterrows()}
points = {(row['playerid'], gw): row[f'GW_{gw}'] for _, row in data.iterrows() for gw in gameweeks}
team = {row['playerid']: row['team_id'] for _, row in data.iterrows()}
position = {row['playerid']: row['position_id'] for _, row in data.iterrows()}

model.x = Var(model.P, model.GW, domain=Binary) 
model.captain = Var(model.P, model.GW, domain=Binary) 

def total_points_rule(model):
    return sum(model.x[p, gw] * points[p, gw] + model.captain[p, gw] * points[p, gw] 
               for p in model.P for gw in model.GW)
model.total_points = Objective(rule=total_points_rule, sense=maximize)

def team_size_rule(model, gw):
    return sum(model.x[p, gw] for p in model.P) == 11
model.team_size = Constraint(model.GW, rule=team_size_rule)

def cost_constraint_rule(model, gw):
    return sum(model.x[p, gw] * cost[p] for p in model.P) <= 85
model.cost_constraint = Constraint(model.GW, rule=cost_constraint_rule)

def team_limit_rule(model, team_id, gw):
    return sum(model.x[p, gw] for p in model.P if team[p] == team_id) <= 4
model.team_limit = Constraint(teams, model.GW, rule=team_limit_rule)

def goalkeeper_rule(model, gw):
    return sum(model.x[p, gw] for p in model.P if position[p] == 3) == 1
model.goalkeeper_constraint = Constraint(model.GW, rule=goalkeeper_rule)

def defenders_rule(model, gw):
    return inequality(3, sum(model.x[p, gw] for p in model.P if position[p] == 2), 5)
model.defenders_constraint = Constraint(model.GW, rule=defenders_rule)

def midfielders_rule(model, gw):
    return inequality(2, sum(model.x[p, gw] for p in model.P if position[p] == 4), 5)
model.midfielders_constraint = Constraint(model.GW, rule=midfielders_rule)

def attackers_rule(model, gw):
    return inequality(1, sum(model.x[p, gw] for p in model.P if position[p] == 1), 3)
model.attackers_constraint = Constraint(model.GW, rule=attackers_rule)

def captain_rule(model, gw):
    return sum(model.captain[p, gw] for p in model.P) == 1
model.captain_constraint = Constraint(model.GW, rule=captain_rule)

def captain_selection_rule(model, p, gw):
    return model.captain[p, gw] <= model.x[p, gw]
model.captain_selection_constraint = Constraint(model.P, model.GW, rule=captain_selection_rule)

def transfer_indicator_rule(model, p, gw):
    if gw == 1:
        return Constraint.Skip
    return model.z[p, gw] >= model.x[p, gw] - model.x[p, gw-1]
model.transfer_indicator_1 = Constraint(model.P, model.GW, rule=transfer_indicator_rule)

def transfer_indicator_rule_2(model, p, gw):
    if gw == 1:
        return Constraint.Skip
    return model.z[p, gw] >= model.x[p, gw-1] - model.x[p, gw]
model.transfer_indicator_2 = Constraint(model.P, model.GW, rule=transfer_indicator_rule_2)

def transfer_limit_rule(model, gw):
    if gw == 1:
        return Constraint.Skip
    return sum(model.z[p, gw] for p in model.P) <= 2
model.transfer_limit = Constraint(model.GW, rule=transfer_limit_rule)

# Captains each gameweek: {(62, 13): 1.0, (121, 2): 1.0, (122, 24): 1.0, (122, 25): 1.0, (152, 19): 1.0, (160, 20): 1.0, (160, 30): 1.0, (160, 33): 1.0, (162, 22): 1.0, (217, 18): 1.0, (248, 4): 1.0, (248, 10): 1.0, (248, 12): 1.0, (248, 36): 1.0, (282, 21): 1.0, (381, 26): 1.0, (390, 34): 1.0, (390, 38): 1.0, (453, 35): 1.0, (453, 37): 1.0, (459, 11): 1.0, (477, 32): 1.0, (484, 6): 1.0, (556, 15): 1.0, (588, 3): 1.0, (616, 5): 1.0, (616, 8): 1.0, (616, 9): 1.0, (617, 17): 1.0, (664, 7): 1.0, (685, 23): 1.0, (685, 27): 1.0, (685, 31): 1.0, (693, 1): 1.0, (717, 29): 1.0, (766, 16): 1.0, (766, 28): 1.0, (813, 14): 1.0}

# %%
def print_teams(selected_players, captains, data):
    player_name_map = {row['playerid']: row['name'] for _, row in data.iterrows()}
    player_position_map = {row['playerid']: row['position'] for _, row in data.iterrows()}

    for gw in range(1, 39):  
        print(f"--- Gameweek {gw} ---")
        
        gw_players = [p for p, gwk in selected_players.keys() if gwk == gw]
        
        if not gw_players:
            print("No players selected for this gameweek.")
            continue

        team = {"Goalkeeper": [], "Defender": [], "Midfielder": [], "Attacker": []}
        
        for player in gw_players:
            position = player_position_map[player]
            name = player_name_map[player]
            if position == 'GK':
                team["Goalkeeper"].append(name)
            elif position == 'DEF':
                team["Defender"].append(name)
            elif position == 'MID':
                team["Midfielder"].append(name)
            elif position == 'FWD':
                team["Attacker"].append(name)

        print("Goalkeeper:")
        for gk in team["Goalkeeper"]:
            print(f"  - {gk}")

        print("Defenders:")
        for df in team["Defender"]:
            print(f"  - {df}")

        print("Midfielders:")
        for mf in team["Midfielder"]:
            print(f"  - {mf}")

        print("Attackers:")
        for fw in team["Attacker"]:
            print(f"  - {fw}")

        gw_captain = [p for p, gwk in captains.keys() if gwk == gw]
        if gw_captain:
            captain_name = player_name_map[gw_captain[0]]
            print(f"Captain: {captain_name} (Points doubled)")

        print("\n")

print_teams(selected_players, captains, data)
# Out:
# --- Gameweek 1 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Raphaël Varane
# Midfielders:
#   - Bryan Mbeumo
#   - Jarrod Bowen
#   - Mohamed Salah
#   - Rodrigo Hernandez
#   - Solly March
# Attackers:
#   - Erling Haaland
#   - Julián Álvarez
# Captain: Raphaël Varane (Points doubled)
#
#
# --- Gameweek 2 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Matty Cash
# Midfielders:
#   - Bryan Mbeumo
#   - Jarrod Bowen
#   - Mohamed Salah
#   - Rodrigo Hernandez
#   - Solly March
# Attackers:
#   - Erling Haaland
#   - Julián Álvarez
# Captain: Bryan Mbeumo (Points doubled)
#
#
# --- Gameweek 3 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Matty Cash
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Jarrod Bowen
#   - Mohamed Salah
#   - Rodrigo Hernandez
# Attackers:
#   - Erling Haaland
#   - Julián Álvarez
# Captain: Matty Cash (Points doubled)
#
#
# --- Gameweek 4 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Matty Cash
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Jarrod Bowen
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Julián Álvarez
# Captain: Erling Haaland (Points doubled)
#
#
# --- Gameweek 5 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Kieran Trippier
#   - Matty Cash
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Julián Álvarez
# Captain: Mohamed Salah (Points doubled)
#
#
# --- Gameweek 6 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Kieran Trippier
#   - Matty Cash
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Ollie Watkins
# Captain: Kieran Trippier (Points doubled)
#
#
# --- Gameweek 7 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Kieran Trippier
#   - Matty Cash
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Ollie Watkins
# Captain: Ollie Watkins (Points doubled)
#
#
# --- Gameweek 8 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Cristian Romero
#   - Joachim Andersen
#   - Kieran Trippier
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Cole Palmer
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Ollie Watkins
# Captain: Mohamed Salah (Points doubled)
#
#
# --- Gameweek 9 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Cristian Romero
#   - Diogo Dalot Teixeira
#   - Kieran Trippier
# Midfielders:
#   - Anthony Gordon
#   - Bryan Mbeumo
#   - Cole Palmer
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Ollie Watkins
# Captain: Mohamed Salah (Points doubled)
#
#
# --- Gameweek 10 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   -
---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Fabian Schär
#   - Gabriel dos Santos Magalhães
# Midfielders:
#   - Cole Palmer
#   - Kai Havertz
#   - Phil Foden
#   - Son Heung-min
# Attackers:
#   - Jean-Philippe Mateta
#   - Ollie Watkins
#   - Rodrigo Muniz Carvalho
# Captain: Son Heung-min (Points doubled)
#
#
# --- Gameweek 29 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Fabian Schär
#   - Gabriel dos Santos Magalhães
# Midfielders:
#   - Cole Palmer
#   - Kai Havertz
#   - Morgan Gibbs-White
#   - Phil Foden
#   - Son Heung-min
# Attackers:
#   - Jean-Philippe Mateta
#   - Rodrigo Muniz Carvalho
# Captain: Rodrigo Muniz Carvalho (Points doubled)
#
#
# --- Gameweek 30 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Fabian Schär
#   - Gabriel dos Santos Magalhães
# Midfielders:
#   - Cole Palmer
#   - Kai Havertz
#   - Morgan Gibbs-White
#   - Phil Foden
#   - Son Heung-min
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Cole Palmer (Points doubled)
#
#
# --- Gameweek 31 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Fabian Schär
#   - Gabriel dos Santos Magalhães
# Midfielders:
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Kai Havertz
#   - Morgan Gibbs-White
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Phil Foden (Points doubled)
#
#
# --- Gameweek 32 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Fabian Schär
#   - Gabriel dos Santos Magalhães
# Midfielders:
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Kai Havertz
#   - Kevin De Bruyne
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Kevin De Bruyne (Points doubled)
#
#
# --- Gameweek 33 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Fabian Schär
#   - Joško Gvardiol
# Midfielders:
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Kai Havertz
#   - Kevin De Bruyne
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Cole Palmer (Points doubled)
#
#
# --- Gameweek 34 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Jarrad Branthwaite
#   - Joško Gvardiol
# Midfielders:
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Kai Havertz
#   - Kevin De Bruyne
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Jean-Philippe Mateta (Points doubled)
#
#
# --- Gameweek 35 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Jarrad Branthwaite
#   - Joško Gvardiol
# Midfielders:
#   - Cole Palmer
#   - Kai Havertz
#   - Kevin De Bruyne
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Erling Haaland
#   - Jean-Philippe Mateta
# Captain: Joško Gvardiol (Points doubled)
#
#
# --- Gameweek 36 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Jarrad Branthwaite
#   - Joško Gvardiol
# Midfielders:
#   - Cole Palmer
#   - Kai Havertz
#   - Michael Olise
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Erling Haaland
#   - Jean-Philippe Mateta
# Captain: Erling Haaland (Points doubled)
#
#
# --- Gameweek 37 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Jarell Quansah
#   - Joško Gvardiol
# Midfielders:
#   - Cole Palmer
#   - Kai Havertz
#   - Michael Olise
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Erling Haaland
#   - Jean-Philippe Mateta
# Captain: Joško Gvardiol (Points doubled)
#
#
# --- Gameweek 38 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Jarell Quansah
#   - Joško Gvardiol
# Midfielders:
#   - Cole Palmer
#   - Eberechi Eze
#   - Kai Havertz
#   - Michael Olise
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Jean-Philippe Mateta (Points doubled)

# %%
import pandas as pd
from pyomo.environ import *

data = pd.read_csv('final_final.csv')

players = data['playerid'].unique()
teams = data['team_id'].unique()
gameweeks = list(range(2, 39))  

model = ConcreteModel()

# Sets
model.P = Set(initialize=players)  
model.GW = Set(initialize=gameweeks)  

# Parameters
cost = {row['playerid']: row['value'] for _, row in data.iterrows()}
points = {(row['playerid'], gw): row[f'GW_{gw}'] for _, row in data.iterrows() for gw in range(1, 39)}
team = {row['playerid']: row['team_id'] for _, row in data.iterrows()}
position = {row['playerid']: row['position_id'] for _, row in data.iterrows()}

# Decision Variables
model.x = Var(model.P, model.GW, domain=Binary)  # Selection of player in a gameweek
model.captain = Var(model.P, model.GW, domain=Binary)  # Selection of captain in a gameweek
model.z = Var(model.P, model.GW, domain=Binary)  # Transfer indicator between consecutive gameweeks

# Objective: Maximize total points for each gameweek based on past data
def total_points_rule(model):
    return sum(model.x[p, gw] * sum(points[p, gwk] * gwk for gwk in range(1, gw)) + 
               model.captain[p, gw] * sum(points[p, gwk] * gwk for gwk in range(1, gw)) 
               for p in model.P for gw in model.GW)
model.total_points = Objective(rule=total_points_rule, sense=maximize)


def team_size_rule(model, gw):
    return sum(model.x[p, gw] for p in model.P) == 11
model.team_size = Constraint(model.GW, rule=team_size_rule)

def cost_constraint_rule(model, gw):
    return sum(model.x[p, gw] * cost[p] for p in model.P) <= 85
model.cost_constraint = Constraint(model.GW, rule=cost_constraint_rule)

def team_limit_rule(model, team_id, gw):
    return sum(model.x[p, gw] for p in model.P if team[p] == team_id) <= 4
model.team_limit = Constraint(teams, model.GW, rule=team_limit_rule)

def goalkeeper_rule(model, gw):
    return sum(model.x[p, gw] for p in model.P if position[p] == 3) == 1
model.goalkeeper_constraint = Constraint(model.GW, rule=goalkeeper_rule)

def defenders_rule(model, gw):
    return inequality(3, sum(model.x[p, gw] for p in model.P if position[p] == 2), 5)
model.defenders_constraint = Constraint(model.GW, rule=defenders_rule)

def midfielders_rule(model, gw):
    return inequality(2, sum(model.x[p, gw] for p in model.P if position[p] == 4), 5)
model.midfielders_constraint = Constraint(model.GW, rule=midfielders_rule)

def attackers_rule(model, gw):
    return inequality(1, sum(model.x[p, gw] for p in model.P if position[p] == 1), 3)
model.attackers_constraint = Constraint(model.GW, rule=attackers_rule)

def captain_rule(model, gw):
    return sum(model.captain[p, gw] for p in model.P) == 1
model.captain_constraint = Constraint(model.GW, rule=captain_rule)

def captain_selection_rule(model, p, gw):
    return model.captain[p, gw] <= model.x[p, gw]
model.captain_selection_constraint = Constraint(model.P, model.GW, rule=captain_selection_rule)

def transfer_indicator_rule(model, p, gw):
    if gw == 2:
        return Constraint.Skip
    return model.z[p, gw] >= model.x[p, gw] - model.x[p, gw-1]
model.transfer_indicator_1 = Constraint(model.P, model.GW, rule=transfer_indicator_rule)

def transfer_indicator_rule_2(model, p, gw):
    if gw == 2:
        return Constraint.Skip
    return model.z[p, gw] >= model.x[p, gw-1] - model.x[p, gw]
model.transfer_indicator_2 = Constraint(model.P, model.GW, rule=transfer_indicator_rule_2)

def transfer_limit_rule(model, gw):
    if gw == 2:
        return Constraint.Skip
    return sum(model.z[p, gw] for p in model.P) <= 1
model.transfer_limit = Constraint(model.GW, rule=transfer_limit_rule)

solver = SolverFactory('cbc')
solver.solve(model)

selected_players = {(p, gw): model.x[p, gw].value for p in model.P for gw in model.GW if model.x[p, gw].value == 1}
captains = {(p, gw): model.captain[p, gw].value for p in model.P for gw in model.GW if model.captain[p, gw].value == 1}
number_of_tranfers = {gw: sum(model.z[p, gw].value for p in model.P if model.z[p, gw].value is not None) for gw in model.GW}
print(number_of_tranfers)
print_teams(selected_players, captains, data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 109
#     107 # Solve the model using CBC solver
#     108 solver = SolverFactory('cbc')
# --> 109 solver.solve(model)
#     111 # Extract solution
#     112 selected_players = {(p, gw): model.x[p, gw].value for p in model.P for gw in model.GW if model.x[p, gw].value == 1}
#
# File ~/.local/lib/python3.12/site-packages/pyomo/opt/base/solvers.py:610, in OptSolver.solve(self, *args, **kwds)
#     607 if not _model is None:
#     608     self._initialize_callbacks(_model)
# --> 610 _status = self._apply_solver()
#     611 if hasattr(self, '_transformation_data'):
#     612     del self._transformation_data
#
# File ~/.local/lib/python3.12/site-packages/pyomo/opt/solver/shellcmd.py:266, in SystemCallSolver._apply_solver(self)
#     263         print("Solver problem files: %s" % str(self._problem_files))
#     265 sys.stdout.flush()
# --> 266 self._rc, self._log = self._execute_command(self._command)
#     267 sys.stdout.flush()
#     268 return Bunch(rc=self._rc, log=self._log)
#
# File ~/.local/lib/python3.12/site-packages/pyomo/opt/solver/shellcmd.py:334, in SystemCallSolver._execute_command(self, command)
#     332 try:
#     333     with TeeStream(*ostreams) as t:
# --> 334         results = subprocess.run(
#     335             command.cmd,
#     336             input=_input,
#     337             env=command.env,
#     338             stdout=t.STDOUT,
#     339             stderr=t.STDERR,
#     340             timeout=timeout,
#     341             universal_newlines=True,
#     342             cwd=command.cwd if "cwd" in command else None,
#     343         )
#     344         t.STDOUT.flush()
#     345         t.STDERR.flush()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
transfer_weeks = {gw: [] for gw in gameweeks[1:]}  

for gw in gameweeks[1:]:
    for p in players:
        if model.x[p, gw].value != model.x[p, gw - 1].value:
            transfer_weeks[gw].append(p)

print("Transfers occurred in the following weeks:")
for gw, transferred_players in transfer_weeks.items():
    if transferred_players:  # Only print weeks with transfers
        print(f"Gameweek {gw}: Transfers: {', '.join(transferred_players)}")
# Out:
# Transfers occurred in the following weeks:

# %%
import pandas as pd
from pyomo.environ import *

# Load the data from CSV
data = pd.read_csv('final_final.csv')

# Extract unique player ids, team ids, and gameweeks
players = data['playerid'].unique()
teams = data['team_id'].unique()

# Initialize model
model = ConcreteModel()

# Sets
model.P = Set(initialize=players)  # Set of players
model.GW = Set(initialize=gameweeks)  # Set of gameweeks
model.z = Var(model.P, model.GW, domain=Binary)  # Transfer indicator between consecutive gameweeks

# Parameters
cost = {row['playerid']: row['value'] for _, row in data.iterrows()}
points = {(row['playerid'], gw): row[f'GW_{gw}'] for _, row in data.iterrows() for gw in gameweeks}
team = {row['playerid']: row['team_id'] for _, row in data.iterrows()}
position = {row['playerid']: row['position_id'] for _, row in data.iterrows()}

# Decision Variables
model.x = Var(model.P, model.GW, domain=Binary)  # Selection of player in a gameweek
model.captain = Var(model.P, model.GW, domain=Binary)  # Selection of captain in a gameweek

# Objective: Maximize total points (with captain's points doubled)
def total_points_rule(model):
    return sum(model.x[p, gw] * points[p, gw] +  model.captain[p, gw] * points[p, gw]
               for p in model.P for gw in model.GW)
model.total_points = Objective(rule=total_points_rule, sense=maximize)

# Constraints

# Team size constraint: Exactly 11 players per gameweek
def team_size_rule(model, gw):
    return sum(model.x[p, gw] for p in model.P) == 11
model.team_size = Constraint(model.GW, rule=team_size_rule)

# Cost constraint: Total cost < 85 for each gameweek
def cost_constraint_rule(model, gw):
    return sum(model.x[p, gw] * cost[p] for p in model.P) <= 85
model.cost_constraint = Constraint(model.GW, rule=cost_constraint_rule)

# Maximum 4 players from any team per gameweek
def team_limit_rule(model, team_id, gw):
    return sum(model.x[p, gw] for p in model.P if team[p] == team_id) <= 4
model.team_limit = Constraint(teams, model.GW, rule=team_limit_rule)

# Exactly 1 goalkeeper per gameweek
def goalkeeper_rule(model, gw):
    return sum(model.x[p, gw] for p in model.P if position[p] == 3) == 1
model.goalkeeper_constraint = Constraint(model.GW, rule=goalkeeper_rule)

# Defenders between 3 and 5 per gameweek
def defenders_rule(model, gw):
    return inequality(3, sum(model.x[p, gw] for p in model.P if position[p] == 2), 5)
model.defenders_constraint = Constraint(model.GW, rule=defenders_rule)

# Midfielders between 2 and 5 per gameweek
def midfielders_rule(model, gw):
    return inequality(2, sum(model.x[p, gw] for p in model.P if position[p] == 4), 5)
model.midfielders_constraint = Constraint(model.GW, rule=midfielders_rule)

# Attackers between 1 and 3 per gameweek
def attackers_rule(model, gw):
    return inequality(1, sum(model.x[p, gw] for p in model.P if position[p] == 1), 3)
model.attackers_constraint = Constraint(model.GW, rule=attackers_rule)

# Exactly 1 captain per gameweek
def captain_rule(model, gw):
    return sum(model.captain[p, gw] for p in model.P) == 1
model.captain_constraint = Constraint(model.GW, rule=captain_rule)

# A player can only be captain if they are selected
def captain_selection_rule(model, p, gw):
    return model.captain[p, gw] <= model.x[p, gw]
model.captain_selection_constraint = Constraint(model.P, model.GW, rule=captain_selection_rule)
# Transfer constraint: Between two gameweeks, at most one player can be transferred
# We will now use binary variable z[p, gw] to represent transfers

# Introduce the transfer variable constraints
# def transfer_indicator_rule(model, p, gw):
#     if gw == 1:
#         return Constraint.Skip
#     return model.z[p, gw] >= model.x[p, gw] - model.x[p, gw-1]
# model.transfer_indicator_1 = Constraint(model.P, model.GW, rule=transfer_indicator_rule)

# def transfer_indicator_rule_2(model, p, gw):
#     if gw == 1:
#         return Constraint.Skip
#     return model.z[p, gw] >= model.x[p, gw-1] - model.x[p, gw]
# model.transfer_indicator_2 = Constraint(model.P, model.GW, rule=transfer_indicator_rule_2)

# # Limit the total number of transfers between two consecutive gameweeks to at most 1
# def transfer_limit_rule(model, gw):
#     if gw == 1:
#         return Constraint.Skip
#     return sum(model.z[p, gw] for p in model.P) <= 1
# model.transfer_limit = Constraint(model.GW, rule=transfer_limit_rule)

# %%
gameweeks = list(range(1, 39))  # 38 gameweeks (GW_1 to GW_38)
print(SolverFactory('cbc').available())
solver = SolverFactory('cbc') # Specify path
solver.solve(model)

# Extract solution
selected_players = {(p, gw): model.x[p, gw].value for p in model.P for gw in model.GW if model.x[p, gw].value == 1}
captains = {(p, gw): model.captain[p, gw].value for p in model.P for gw in model.GW if model.captain[p, gw].value == 1}

print("Selected players each gameweek:", selected_players)
print("Captains each gameweek:", captains)
# Out:
# True
# %%
print_teams(selected_players, captains, data)
# Out:
# --- Gameweek 1 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Aaron Wan-Bissaka
#   - Axel Disasi
#   - Joachim Andersen
#   - Raphaël Varane
# Midfielders:
#   - Bukayo Saka
#   - Harvey Barnes
#   - Jarrod Bowen
#   - Rodrigo Hernandez
# Attackers:
#   - Alexander Isak
#   - Erling Haaland
# Captain: Raphaël Varane (Points doubled)
#
#
# --- Gameweek 2 ---
# Goalkeeper:
#   - Guglielmo Vicario
# Defenders:
#   - Lucas Digne
#   - Pervis Estupiñán
#   - Serge Aurier
# Midfielders:
#   - Bryan Mbeumo
#   - Diogo Teixeira da Silva
#   - Kaoru Mitoma
#   - Leon Bailey
#   - Solly March
# Attackers:
#   - Michail Antonio
#   - Yoane Wissa
# Captain: Bryan Mbeumo (Points doubled)
#
#
# --- Gameweek 3 ---
# Goalkeeper:
#   - José Malheiro de Sá
# Defenders:
#   - Destiny Udogie
#   - Joachim Andersen
#   - Malo Gusto
#   - Matty Cash
# Midfielders:
#   - Bruno Borges Fernandes
#   - Jarrod Bowen
#   - Moussa Diaby
#   - Raheem Sterling
#   - Rodrigo Hernandez
# Attackers:
#   - Darwin Núñez Ribeiro
# Captain: Raheem Sterling (Points doubled)
#
#
# --- Gameweek 4 ---
# Goalkeeper:
#   - Alisson Ramses Becker
# Defenders:
#   - Kurt Zouma
#   - Trent Alexander-Arnold
#   - Willy Boly
# Midfielders:
#   - Billy Gilmour
#   - Declan Rice
#   - Pedro Lomba Neto
#   - Son Heung-min
# Attackers:
#   - Erling Haaland
#   - Evan Ferguson
#   - Julián Álvarez
# Captain: Erling Haaland (Points doubled)
#
#
# --- Gameweek 5 ---
# Goalkeeper:
#   - Norberto Murara Neto
# Defenders:
#   - Andrew Robertson
#   - Sven Botman
#   - Timothy Castagne
# Midfielders:
#   - Bernardo Veiga de Carvalho e Silva
#   - Callum Hudson-Odoi
#   - Douglas Luiz Soares de Paulo
#   - Leandro Trossard
#   - Pascal Groß
# Attackers:
#   - Julián Álvarez
#   - Odsonne Edouard
# Captain: Bernardo Veiga de Carvalho e Silva (Points doubled)
#
#
# --- Gameweek 6 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Dan Burn
#   - James Tarkowski
#   - Jonny Evans
#   - Kieran Trippier
#   - Sven Botman
# Midfielders:
#   - Bruno Guimarães Rodriguez Moura
#   - Bukayo Saka
#   - Kaoru Mitoma
#   - Son Heung-min
# Attackers:
#   - Carlton Morris
# Captain: Kieran Trippier (Points doubled)
#
#
# --- Gameweek 7 ---
# Goalkeeper:
#   - Sam Johnstone
# Defenders:
#   - Benjamin White
#   - Joachim Andersen
#   - Kieran Trippier
#   - Levi Colwill
#   - Vladimír Coufal
# Midfielders:
#   - Martin Ødegaard
#   - Miguel Almirón Rejala
#   - Nicolás Domínguez
# Attackers:
#   - Carlton Morris
#   - Ollie Watkins
# Captain: Ollie Watkins (Points doubled)
#
#
# --- Gameweek 8 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Marc Guéhi
#   - Micky van de Ven
#   - Pau Torres
# Midfielders:
#   - Cole Palmer
#   - Jack Harrison
#   - Mohamed Salah
#   - Raheem Sterling
#   - Scott McTominay
# Attackers:
#   - Alexander Isak
# Captain: Raheem Sterling (Points doubled)
#
#
# --- Gameweek 9 ---
# Goalkeeper:
#   - Alisson Ramses Becker
# Defenders:
#   - Cristian Romero
#   - Diogo Dalot Teixeira
#   - Kieran Trippier
# Midfielders:
#   - Bryan Mbeumo
#   - Douglas Luiz Soares de Paulo
#   - Jacob Murphy
#   - Mohamed Salah
#   - Son Heung-min
# Attackers:
#   - Chris Wood
#   - Ollie Watkins
# Captain: Jacob Murphy (Points doubled)
#
#
# --- Gameweek 10 ---
# Goalkeeper:
#   - Ederson Santana de Moraes
# Defenders:
#   - Ethan Pinnock
#   - Kyle Walker
#   - Oleksandr Zinchenko
# Midfielders:
#   - Bryan Mbeumo
#   - Dominik Szoboszlai
#   - João Palhinha Gonçalves
#   - Moussa Diaby
# Attackers:
#   - Callum Wilson
#   - Eddie Nketiah
#   - Erling Haaland
# Captain: Eddie Nketiah (Points doubled)
#
#
# --- Gameweek 11 ---
# Goalkeeper:
#   - Sam Johnstone
# Defenders:
#   - Harry Toffolo
#   - Olu Aina
#   - Tyrick Mitchell
#   - Vitalii Mykolenko
# Midfielders:
#   - Bernardo Veiga de Carvalho e Silva
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Jérémy Doku
#   - Mohammed Kudus
# Attackers:
#   - Nicolas Jackson
# Captain: Jérémy Doku (Points doubled)
#
#
# --- Gameweek 12 ---
# Goalkeeper:
#   - Norberto Murara Neto
# Defenders:
#   - Konstantinos Tsimikas
#   - Oleksandr Zinchenko
#   - Victor Lindelöf
# Midfielders:
#   - Abdoulaye Doucouré
#   - James Ward-Prowse
#   - Leandro Trossard
#   - Mohamed Salah
#   - Pablo Sarabia
# Attackers:
#   - Dominic Solanke
#   - Erling Haaland
# Captain: Erling Haaland (Points doubled)
#
#
# --- Gameweek 13 ---
# Goalkeeper:
#   - André Onana
# Defenders:
#   - Diogo Dalot Teixeira
#   - Oleksandr Zinchenko
#   - Teden Mengi
# Midfielders:
#   - Anthony Gordon
#   - Marcus Tavernier
#   - Michael Olise
#   - Morgan Gibbs-White
#   - Willian Borges da Silva
# Attackers:
#   - Anthony Martial
#   - João Pedro Junqueira de Jesus
# Captain: Marcus Tavernier (Points doubled)
#
#
# --- Gameweek 14 ---
# Goalkeeper:
#   - Daniel Bentley
# Defenders:
#   - Ben Mee
#   - Jordan Beyer
#   - Kieran Trippier
#   - Takehiro Tomiyasu
#   - Trent Alexander-Arnold
# Midfielders:
#   - Dejan Kulusevski
#   - Enzo Fernández
#   - Martin Ødegaard
# Attackers:
#   - Ollie Watkins
#   - Zeki Amdouni
# Captain: Ben Mee (Points doubled)
#
#
# --- Gameweek 15 ---
---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Conor Bradley
#   - Destiny Udogie
#   - Fabian Schär
# Midfielders:
#   - Eberechi Eze
#   - Luis Díaz
#   - Michael Olise
#   - Pedro Lomba Neto
# Attackers:
#   - Elijah Adebayo
#   - Julián Álvarez
#   - Rasmus Højlund
# Captain: Conor Bradley (Points doubled)
#
#
# --- Gameweek 23 ---
# Goalkeeper:
#   - Mark Flekken
# Defenders:
#   - Alexandre Moreno Lopera
#   - Kieran Trippier
#   - Lewis Dunk
# Midfielders:
#   - Alejandro Garnacho
#   - Phil Foden
#   - Richarlison de Andrade
#   - Ross Barkley
#   - Sean Longstaff
# Attackers:
#   - Matheus Santos Carneiro Da Cunha
#   - Ollie Watkins
# Captain: Phil Foden (Points doubled)
#
#
# --- Gameweek 24 ---
# Goalkeeper:
#   - Mark Flekken
# Defenders:
#   - Gabriel dos Santos Magalhães
#   - Sergio Reguilón
#   - William Saliba
# Midfielders:
#   - Bruno Guimarães Rodriguez Moura
#   - Bukayo Saka
#   - Conor Gallagher
#   - Declan Rice
#   - Vini de Souza Costa
# Attackers:
#   - Erling Haaland
#   - Rodrigo Muniz Carvalho
# Captain: Declan Rice (Points doubled)
#
#
# --- Gameweek 25 ---
# Goalkeeper:
#   - Ederson Santana de Moraes
# Defenders:
#   - Kyle Walker
#   - Lewis Dunk
#   - Manuel Akanji
# Midfielders:
#   - Alexis Mac Allister
#   - Bukayo Saka
#   - João Victor Gomes da Silva
#   - Martin Ødegaard
#   - Simon Adingra
# Attackers:
#   - Cody Gakpo
#   - Ollie Watkins
# Captain: Alexis Mac Allister (Points doubled)
#
#
# --- Gameweek 26 ---
# Goalkeeper:
#   - Ederson Santana de Moraes
# Defenders:
#   - Chris Richards
#   - Emerson Palmieri dos Santos
#   - Lewis Dunk
#   - Rayan Aït-Nouri
# Midfielders:
#   - Douglas Luiz Soares de Paulo
#   - Jarrod Bowen
#   - Jordan Ayew
#   - Kai Havertz
#   - Leon Bailey
# Attackers:
#   - Ollie Watkins
# Captain: Jarrod Bowen (Points doubled)
#
#
# --- Gameweek 27 ---
# Goalkeeper:
#   - Alphonse Areola
# Defenders:
#   - Benjamin White
#   - Cristian Romero
#   - Fabian Schär
# Midfielders:
#   - Gabriel Martinelli Silva
#   - Harry Wilson
#   - Kai Havertz
#   - Lewis Cook
#   - Phil Foden
# Attackers:
#   - Ollie Watkins
#   - Rodrigo Muniz Carvalho
# Captain: Phil Foden (Points doubled)
#
#
# --- Gameweek 28 ---
# Goalkeeper:
#   - André Onana
# Defenders:
#   - Benjamin White
#   - John Stones
#   - Rayan Aït-Nouri
# Midfielders:
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Dango Ouattara
#   - Ryan Christie
#   - Son Heung-min
# Attackers:
#   - Antoine Semenyo
#   - Enes Ünal
# Captain: Son Heung-min (Points doubled)
#
#
# --- Gameweek 29 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Antonee Robinson
#   - Kristoffer Ajer
#   - Reece Burke
#   - Timothy Castagne
#   - Vladimír Coufal
# Midfielders:
#   - Jacob Bruun Larsen
#   - Morgan Gibbs-White
# Attackers:
#   - Chris Wood
#   - Michail Antonio
#   - Rodrigo Muniz Carvalho
# Captain: Rodrigo Muniz Carvalho (Points doubled)
#
#
# --- Gameweek 30 ---
# Goalkeeper:
#   - Emiliano Martínez Romero
# Defenders:
#   - Ezri Konsa Ngoyo
#   - Joško Gvardiol
#   - Kristoffer Ajer
# Midfielders:
#   - Ben Brereton
#   - Cole Palmer
#   - Harvey Barnes
#   - Mohammed Kudus
#   - Moussa Diaby
# Attackers:
#   - Alexander Isak
#   - Oliver McBurnie
# Captain: Ben Brereton (Points doubled)
#
#
# --- Gameweek 31 ---
# Goalkeeper:
#   - Mark Flekken
# Defenders:
#   - Adam Smith
#   - Kurt Zouma
#   - Lewis Hall
#   - Oleksandr Zinchenko
# Midfielders:
#   - Alejandro Garnacho
#   - Cole Palmer
#   - Morgan Gibbs-White
#   - Phil Foden
#   - Rodrigo Hernandez
# Attackers:
#   - Alexander Isak
# Captain: Phil Foden (Points doubled)
#
#
# --- Gameweek 32 ---
# Goalkeeper:
#   - Martin Dubravka
# Defenders:
#   - Micky van de Ven
#   - Pedro Porro
#   - Thiago Emiliano da Silva
# Midfielders:
#   - Bruno Guimarães Rodriguez Moura
#   - Bukayo Saka
#   - Kai Havertz
#   - Kevin De Bruyne
#   - Kobbie Mainoo
# Attackers:
#   - Dominic Calvert-Lewin
#   - Ollie Watkins
# Captain: Kevin De Bruyne (Points doubled)
#
#
# --- Gameweek 33 ---
# Goalkeeper:
#   - Bernd Leno
# Defenders:
#   - Fabian Schär
#   - Joško Gvardiol
#   - Lucas Digne
# Midfielders:
#   - Andreas Hoelgebaum Pereira
#   - Anthony Gordon
#   - Bruno Borges Fernandes
#   - Cole Palmer
#   - Jérémy Doku
# Attackers:
#   - Alexander Isak
#   - Nicolas Jackson
# Captain: Cole Palmer (Points doubled)
#
#
# --- Gameweek 34 ---
# Goalkeeper:
#   - Jordan Pickford
# Defenders:
#   - Benjamin White
#   - Jarrad Branthwaite
#   - Kyle Walker
#   - Lorenz Assignon
# Midfielders:
#   - Bruno Borges Fernandes
#   - Dwight McNeil
#   - Kai Havertz
#   - Martin Ødegaard
#   - Phil Foden
# Attackers:
#   - Jean-Philippe Mateta
# Captain: Jean-Philippe Mateta (Points doubled)
#
#
# --- Gameweek 35 ---
# Goalkeeper:
#   - Đorđe Petrović
# Defenders:
#   - Joško Gvardiol
#   - Marcos Senesi
#   - Trevoh Chalobah
# Midfielders:
#   - Bukayo Saka
#   - Conor Gallagher
#   - Jarrod Bowen
#   - Kai Havertz
#   - Noni Madueke
# Attackers:
#   - Alexander Isak
#   - Enes Ünal
# Captain: Trevoh Chalobah (Points doubled)
#
#
# --- Gameweek 36 ---
# Goalkeeper:
#   - Robin Olsen
# Defenders:
#   - Andrew Robertson
#   - Daniel Muñoz
#   - Tyrick Mitchell
# Midfielders:
#   - Callum Hudson-Odoi
#   - Declan Rice
#   - Michael Olise
#   - Mohamed Salah
#   - Noni Madueke
# Attackers:
#   - Erling Haaland
#   - Nicolas Jackson
# Captain: Erling Haaland (Points doubled)
#
#
# --- Gameweek 37 ---
# Goalkeeper:
#   - Ederson Santana de Moraes
# Defenders:
#   - Joško Gvardiol
#   - Malo Gusto
#   - Micky van de Ven
#   - Rúben Gato Alves Dias
# Midfielders:
#   - Amad Diallo
#   - Bryan Mbeumo
#   - Cole Palmer
#   - Michael Olise
# Attackers:
#   - Erling Haaland
#   - Jhon Durán
# Captain: Joško Gvardiol (Points doubled)
#
#
# --- Gameweek 38 ---
# Goalkeeper:
#   - André Onana
# Defenders:
#   - Diogo Dalot Teixeira
#   - Jarell Quansah
#   - Pedro Porro
# Midfielders:
#   - Bruno Guimarães Rodriguez Moura
#   - Dejan Kulusevski
#   - Eberechi Eze
#   - Harry Wilson
#   - Phil Foden
# Attackers:
#   - Alexander Isak
#   - Jean-Philippe Mateta
# Captain: Jean-Philippe Mateta (Points doubled)

# %%
def print_teams(selected_players, captains, data):
    finaltotal=0
    player_name_map = {row['playerid']: row['name'] for _, row in data.iterrows()}
    player_position_map = {row['playerid']: row['position'] for _, row in data.iterrows()}
    
    for gw in range(1, 39):  
        oops = "GW_" + str(gw)
        player_points_map = {row['playerid']: row[oops] for _, row in data.iterrows()}
        print(f"--- Gameweek {gw} ---")
        
        gw_players = [p for p, gwk in selected_players.keys() if gwk == gw]
        
        if not gw_players:
            print("No players selected for this gameweek.")
            continue

        team = {"Goalkeeper": [], "Defender": [], "Midfielder": [], "Attacker": []}
        total_points = 0
        for player in gw_players:
            position = player_position_map[player]
            name = player_name_map[player]
            points = player_points_map.get(player, 0)  # Get points for this gameweek
            
            if position == 'GK':
                team["Goalkeeper"].append((name, points))
            elif position == 'DEF':
                team["Defender"].append((name, points))
            elif position == 'MID':
                team["Midfielder"].append((name, points))
            elif position == 'FWD':
                team["Attacker"].append((name, points))
            
            total_points += points  # Add player's points to total

        # Print players and their points by position
        print("Goalkeeper:")
        for gk, points in team["Goalkeeper"]:
            print(f"  - {gk} (Points: {points})")

        print("Defenders:")
        for df, points in team["Defender"]:
            print(f"  - {df} (Points: {points})")

        print("Midfielders:")
        for mf, points in team["Midfielder"]:
            print(f"  - {mf} (Points: {points})")

        print("Attackers:")
        for fw, points in team["Attacker"]:
            print(f"  - {fw} (Points: {points})")

        # Check if there's a captain and apply doubled points
        gw_captain = [p for p, gwk in captains.keys() if gwk == gw]
        if gw_captain:
            captain = gw_captain[0]
            captain_name = player_name_map[captain]
            captain_points = player_points_map.get(captain, 0)
            total_points += captain_points  # Already added once; add again for doubled points
            print(f"Captain: {captain_name} (Points: {captain_points} x2)")

        print(f"Total points for Gameweek {gw}: {total_points}")
        finaltotal+=total_points
        print("\n")
    print("Total Points over all gameweeks:", finaltotal )

# Example call to the function
print_teams(selected_players, captains, data)
# Out:
# --- Gameweek 1 ---
# Goalkeeper:
#   - Bernd Leno (Points: 12)
# Defenders:
#   - Cristian Romero (Points: 7)
#   - Joachim Andersen (Points: 9)
#   - Raphaël Varane (Points: 14)
# Midfielders:
#   - Bryan Mbeumo (Points: 7)
#   - Jarrod Bowen (Points: 9)
#   - Mohamed Salah (Points: 5)
#   - Rodrigo Hernandez (Points: 13)
#   - Solly March (Points: 9)
# Attackers:
#   - Erling Haaland (Points: 13)
#   - Julián Álvarez (Points: 5)
# Captain: Raphaël Varane (Points: 14 x2)
# Total points for Gameweek 1: 117
#
#
# --- Gameweek 2 ---
# Goalkeeper:
#   - Bernd Leno (Points: 2)
# Defenders:
#   - Cristian Romero (Points: 6)
#   - Joachim Andersen (Points: 2)
#   - Matty Cash (Points: 6)
# Midfielders:
#   - Bryan Mbeumo (Points: 16)
#   - Jarrod Bowen (Points: 2)
#   - Mohamed Salah (Points: 5)
#   - Rodrigo Hernandez (Points: 3)
#   - Solly March (Points: 15)
# Attackers:
#   - Erling Haaland (Points: 2)
#   - Julián Álvarez (Points: 7)
# Captain: Bryan Mbeumo (Points: 16 x2)
# Total points for Gameweek 2: 82
#
#
# --- Gameweek 3 ---
# Goalkeeper:
#   - Bernd Leno (Points: 5)
# Defenders:
#   - Cristian Romero (Points: 7)
#   - Joachim Andersen (Points: 11)
#   - Matty Cash (Points: 17)
# Midfielders:
#   - Anthony Gordon (Points: 10)
#   - Bryan Mbeumo (Points: 2)
#   - Jarrod Bowen (Points: 12)
#   - Mohamed Salah (Points: 5)
#   - Rodrigo Hernandez (Points: 10)
# Attackers:
#   - Erling Haaland (Points: 4)
#   - Julián Álvarez (Points: 2)
# Captain: Matty Cash (Points: 17 x2)
# Total points for Gameweek 3: 102
#
#
# --- Gameweek 4 ---
# Goalkeeper:
#   - Bernd Leno (Points: 0)
# Defenders:
#   - Cristian Romero (Points: 7)
#   - Joachim Andersen (Points: 1)
#   - Matty Cash (Points: -1)
# Midfielders:
#   - Anthony Gordon (Points: 1)
#   - Bryan Mbeumo (Points: 8)
#   - Jarrod Bowen (Points: 7)
#   - Mohamed Salah (Points: 8)
#   - Son Heung-min (Points: 20)
# Attackers:
#   - Erling Haaland (Points: 20)
#   - Julián Álvarez (Points: 14)
# Captain: Erling Haaland (Points: 20 x2)
# Total points for Gameweek 4: 105
#
#
# --- Gameweek 5 ---
# Goalkeeper:
#   - Bernd Leno (Points: 6)
# Defenders:
#   - Cristian Romero (Points: 2)
#   - Joachim Andersen (Points: 1)
#   - Kieran Trippier (Points: 8)
#   - Matty Cash (Points: 1)
# Midfielders:
#   - Anthony Gordon (Points: 5)
#   - Bryan Mbeumo (Points: 2)
#   - Mohamed Salah (Points: 10)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Erling Haaland (Points: 6)
#   - Julián Álvarez (Points: 9)
# Captain: Mohamed Salah (Points: 10 x2)
# Total points for Gameweek 5: 62
#
#
# --- Gameweek 6 ---
# Goalkeeper:
#   - Bernd Leno (Points: 10)
# Defenders:
#   - Cristian Romero (Points: -2)
#   - Joachim Andersen (Points: 6)
#   - Kieran Trippier (Points: 18)
#   - Matty Cash (Points: 6)
# Midfielders:
#   - Anthony Gordon (Points: 12)
#   - Bryan Mbeumo (Points: 1)
#   - Mohamed Salah (Points: 10)
#   - Son Heung-min (Points: 14)
# Attackers:
#   - Erling Haaland (Points: 6)
#   - Ollie Watkins (Points: 9)
# Captain: Kieran Trippier (Points: 18 x2)
# Total points for Gameweek 6: 108
#
#
# --- Gameweek 7 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 1)
# Defenders:
#   - Cristian Romero (Points: 1)
#   - Joachim Andersen (Points: 15)
#   - Kieran Trippier (Points: 12)
#   - Matty Cash (Points: 6)
# Midfielders:
#   - Anthony Gordon (Points: 5)
#   - Bryan Mbeumo (Points: 2)
#   - Mohamed Salah (Points: 1)
#   - Son Heung-min (Points: 7)
# Attackers:
#   - Erling Haaland (Points: 2)
#   - Ollie Watkins (Points: 23)
# Captain: Ollie Watkins (Points: 23 x2)
# Total points for Gameweek 7: 98
#
#
# --- Gameweek 8 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 9)
# Defenders:
#   - Cristian Romero (Points: 8)
#   - Joachim Andersen (Points: 6)
#   - Kieran Trippier (Points: 6)
# Midfielders:
#   - Anthony Gordon (Points: 0)
#   - Bryan Mbeumo (Points: 2)
#   - Cole Palmer (Points: 12)
#   - Mohamed Salah (Points: 15)
#   - Son Heung-min (Points: 3)
# Attackers:
#   - Erling Haaland (Points: 2)
#   - Ollie Watkins (Points: 5)
# Captain: Mohamed Salah (Points: 15 x2)
# Total points for Gameweek 8: 83
#
#
# --- Gameweek 9 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Cristian Romero (Points: 8)
#   - Diogo Dalot Teixeira (Points: 11)
#   - Kieran Trippier (Points: 10)
# Midfielders:
#   - Anthony Gordon (Points: 8)
#   - Bryan Mbeumo (Points: 14)
#   - Cole Palmer (Points: 6)
#   - Mohamed Salah (Points: 16)
#   - Son Heung-min (Points: 14)
# Attackers:
#   - Erling Haaland (Points: 8)
#   - Ollie Watkins (Points: 11)
# Captain: Mohamed Salah (Points: 16 x2)
# Total points for Gameweek 9: 124
#
#
# --- Gameweek 10 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 5)
# Defenders:
#   - Diogo Dalot Teixeira (Points: 1)
#   - Kieran Trippier (Points: 0)
#   - Vitalii Mykolenko (Points: 8)
# Midfielders:
#   - Anthony Gordon (Points: 2)
#   - Bryan Mbeumo (Points: 13)
#   - Cole Palmer (Points: 2)
#   - Mohamed Salah (Points: 8)
#   - Son Heung-min (Points: 10)
# Attackers:
#   - Erling Haaland (Points: 16)
#   - Ollie Watkins (Points: 2)
# Captain: Erling Haaland (Points: 16 x2)
# Total points for Gameweek 10: 83
#
#
# --- Gameweek 11 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Diogo Dalot Teixeira (Points: 6)
#   - Kieran Trippier (Points: 9)
#   - Vitalii Mykolenko (Points: 11)
# Midfielders:
#   - Anthony Gordon (Points: 7)
#   - Cole Palmer (Points: 12)
#   - Jérémy Doku (Points: 22)
#   - Mohamed Salah (Points: 2)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Erling Haaland (Points: 1)
#   - Ollie Watkins (Points: 2)
# Captain: Jérémy Doku (Points: 22 x2)
# Total points for Gameweek 11: 98
#
#
# --- Gameweek 12 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Diogo Dalot Teixeira (Points: 6)
#   - Kieran Trippier (Points: 1)
#   - Vitalii Mykolenko (Points: 9)
# Midfielders:
#   - Anthony Gordon (Points: 2)
#   - Cole Palmer (Points: 6)
#   - Mohamed Salah (Points: 16)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Dominic Solanke (Points: 13)
#   - Erling Haaland (Points: 16)
#   - Ollie Watkins (Points: 6)
# Captain: Erling Haaland (Points: 16 x2)
# Total points for Gameweek 12: 95
#
#
# --- Gameweek 13 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 1)
# Defenders:
#   - Diogo Dalot Teixeira (Points: 12)
#   - Kieran Trippier (Points: 1)
#   - Vitalii Mykolenko (Points: 1)
# Midfielders:
#   - Anthony Gordon (Points: 13)
#   - Cole Palmer (Points: 2)
#   - Mohamed Salah (Points: 5)
#   - Mohammed Kudus (Points: 10)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Dominic Solanke (Points: 2)
#   - Ollie Watkins (Points: 5)
# Captain: Anthony Gordon (Points: 13 x2)
# Total points for Gameweek 13: 67
#
#
# --- Gameweek 14 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 7)
# Defenders:
#   - Kieran Trippier (Points: 12)
#   - Trent Alexander-Arnold (Points: 13)
#   - Vitalii Mykolenko (Points: 6)
# Midfielders:
#   - Anthony Gordon (Points: 10)
#   - Cole Palmer (Points: 1)
#   - Mohamed Salah (Points: 5)
#   - Mohammed Kudus (Points: 9)
#   - Son Heung-min (Points: 10)
# Attackers:
#   - Dominic Solanke (Points: 6)
#   - Ollie Watkins (Points: 11)
# Captain: Trent Alexander-Arnold (Points: 13 x2)
# Total points for Gameweek 14: 103
#
#
# --- Gameweek 15 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 7)
# Defenders:
#   - Marcos Senesi (Points: 14)
#   - Trent Alexander-Arnold (Points: 12)
#   - Vitalii Mykolenko (Points: 6)
# Midfielders:
#   - Anthony Gordon (Points: 2)
#   - Cole Palmer (Points: 8)
#   - Mohamed Salah (Points: 3)
#   - Mohammed Kudus (Points: 2)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Dominic Solanke (Points: 2)
#   - Ollie Watkins (Points: 1)
# Captain: Marcos Senesi (Points: 14 x2)
# Total points for Gameweek 15: 73
#
#
# --- Gameweek 16 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 10)
# Defenders:
#   - Marcos Senesi (Points: 15)
#   - Trent Alexander-Arnold (Points: 4)
#   - Vitalii Mykolenko (Points: 7)
# Midfielders:
#   - Cole Palmer (Points: 1)
#   - Mohamed Salah (Points: 13)
#   - Mohammed Kudus (Points: 2)
#   - Richarlison de Andrade (Points: 15)
#   - Son Heung-min (Points: 17)
# Attackers:
#   - Dominic Solanke (Points: 7)
#   - Ollie Watkins (Points: 2)
# Captain: Son Heung-min (Points: 17 x2)
# Total points for Gameweek 16: 110
#
#
# --- Gameweek 17 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 6)
# Defenders:
#   - Gabriel dos Santos Magalhães (Points: 6)
#   - Marcos Senesi (Points: 0)
#   - Trent Alexander-Arnold (Points: 9)
# Midfielders:
#   - Cole Palmer (Points: 14)
#   - Mohamed Salah (Points: 3)
#   - Mohammed Kudus (Points: 16)
#   - Richarlison de Andrade (Points: 9)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Dominic Solanke (Points: 0)
#   - Ollie Watkins (Points: 9)
# Captain: Mohammed Kudus (Points: 16 x2)
# Total points for Gameweek 17: 90
#
#
# --- Gameweek 18 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Gabriel dos Santos Magalhães (Points: 10)
#   - Marcos Senesi (Points: 5)
#   - Trent Alexander-Arnold (Points: 5)
# Midfielders:
#   - Cole Palmer (Points: 1)
#   - Mohamed Salah (Points: 7)
#   - Mohammed Kudus (Points: 9)
#   - Richarlison de Andrade (Points: 8)
# Attackers:
#   - Chris Wood (Points: 11)
#   - Dominic Solanke (Points: 17)
#   - Ollie Watkins (Points: 2)
# Captain: Dominic Solanke (Points: 17 x2)
# Total points for Gameweek 18: 94
#
#
# --- Gameweek 19 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Gabriel dos Santos Magalhães (Points: 1)
#   - Marcos Senesi (Points: 6)
#   - Trent Alexander-Arnold (Points: 8)
# Midfielders:
#   - Cole Palmer (Points: 0)
#   - Mohamed Salah (Points: 3)
#   - Phil Foden (Points: 8)
#   - Richarlison de Andrade (Points: 1)
# Attackers:
#   - Chris Wood (Points: 17)
#   - Dominic Solanke (Points: 6)
#   - Ollie Watkins (Points: 2)
# Captain: Chris Wood (Points: 17 x2)
# Total points for Gameweek 19: 71
#
#
# --- Gameweek 20 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Conor Bradley (Points: 0)
#   - Gabriel dos Santos Magalhães (Points: 1)
#   - Marcos Senesi (Points: 0)
# Midfielders:
#   - Cole Palmer (Points: 18)
#   - Mohamed Salah (Points: 16)
#   - Phil Foden (Points: 12)
#   - Richarlison de Andrade (Points: 8)
# Attackers:
#   - Chris Wood (Points: 2)
#   - Dominic Solanke (Points: 2)
#   - Ollie Watkins (Points: 8)
# Captain: Cole Palmer (Points: 18 x2)
# Total points for Gameweek 20: 87
#
#
# --- Gameweek 21 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 9)
# Defenders:
#   - Conor Bradley (Points: 8)
#   - Gabriel dos Santos Magalhães (Points: 17)
#   - Marcos Senesi (Points: 0)
# Midfielders:
#   - Bukayo Saka (Points: 3)
#   - Cole Palmer (Points: 10)
#   - Phil Foden (Points: 2)
#   - Richarlison de Andrade (Points: 8)
# Attackers:
#   - Chris Wood (Points: 8)
#   - Dominic Solanke (Points: 2)
#   - Ollie Watkins (Points: 1)
# Captain: Gabriel dos Santos Magalhães (Points: 17 x2)
# Total points for Gameweek 21: 85
#
#
# --- Gameweek 22 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 10)
# Defenders:
#   - Conor Bradley (Points: 21)
#   - Fabian Schär (Points: 17)
#   - Gabriel dos Santos Magalhães (Points: 2)
#   - Marcos Senesi (Points: 2)
# Midfielders:
#   - Bukayo Saka (Points: 10)
#   - Cole Palmer (Points: 2)
#   - Phil Foden (Points: 6)
#   - Richarlison de Andrade (Points: 7)
# Attackers:
#   - Dominic Solanke (Points: 8)
#   - Ollie Watkins (Points: 7)
# Captain: Conor Bradley (Points: 21 x2)
# Total points for Gameweek 22: 113
#
#
# --- Gameweek 23 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Fabian Schär (Points: 0)
#   - Gabriel dos Santos Magalhães (Points: -1)
#   - Marcos Senesi (Points: 1)
# Midfielders:
#   - Bukayo Saka (Points: 9)
#   - Cole Palmer (Points: 8)
#   - Phil Foden (Points: 20)
#   - Richarlison de Andrade (Points: 15)
# Attackers:
#   - Dominic Solanke (Points: 2)
#   - Ollie Watkins (Points: 18)
#   - Rodrigo Muniz Carvalho (Points: 8)
# Captain: Phil Foden (Points: 20 x2)
# Total points for Gameweek 23: 102
#
#
# --- Gameweek 24 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 1)
# Defenders:
#   - Benjamin White (Points: 9)
#   - Fabian Schär (Points: 7)
#   - Gabriel dos Santos Magalhães (Points: 12)
#   - Marcos Senesi (Points: 8)
# Midfielders:
#   - Bukayo Saka (Points: 15)
#   - Cole Palmer (Points: 10)
#   - Phil Foden (Points: 3)
# Attackers:
#   - Dominic Solanke (Points: 4)
#   - Ollie Watkins (Points: 2)
#   - Rodrigo Muniz Carvalho (Points: 13)
# Captain: Bukayo Saka (Points: 15 x2)
# Total points for Gameweek 24: 99
#
#
# --- Gameweek 25 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 3)
# Defenders:
#   - Benjamin White (Points: 6)
#   - Fabian Schär (Points: 3)
#   - Gabriel dos Santos Magalhães (Points: 6)
# Midfielders:
#   - Bukayo Saka (Points: 15)
#   - Cole Palmer (Points: 2)
#   - Kai Havertz (Points: 12)
#   - Phil Foden (Points: 5)
# Attackers:
#   - Dominic Solanke (Points: 12)
#   - Ollie Watkins (Points: 13)
#   - Rodrigo Muniz Carvalho (Points: 8)
# Captain: Bukayo Saka (Points: 15 x2)
# Total points for Gameweek 25: 100
#
#
# --- Gameweek 26 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 4)
# Defenders:
#   - Benjamin White (Points: 2)
#   - Fabian Schär (Points: 0)
#   - Gabriel dos Santos Magalhães (Points: 2)
# Midfielders:
#   - Bukayo Saka (Points: 10)
#   - Cole Palmer (Points: 0)
#   - Jarrod Bowen (Points: 20)
#   - Kai Havertz (Points: 14)
#   - Phil Foden (Points: 11)
# Attackers:
#   - Ollie Watkins (Points: 9)
#   - Rodrigo Muniz Carvalho (Points: 2)
# Captain: Jarrod Bowen (Points: 20 x2)
# Total points for Gameweek 26: 94
#
#
# --- Gameweek 27 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 0)
# Defenders:
#   - Benjamin White (Points: 13)
#   - Fabian Schär (Points: 12)
#   - Gabriel dos Santos Magalhães (Points: 6)
# Midfielders:
#   - Bukayo Saka (Points: 7)
#   - Cole Palmer (Points: 5)
#   - Kai Havertz (Points: 14)
#   - Phil Foden (Points: 15)
#   - Son Heung-min (Points: 7)
# Attackers:
#   - Ollie Watkins (Points: 13)
#   - Rodrigo Muniz Carvalho (Points: 11)
# Captain: Phil Foden (Points: 15 x2)
# Total points for Gameweek 27: 118
#
#
# --- Gameweek 28 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 3)
# Defenders:
#   - Benjamin White (Points: 11)
#   - Fabian Schär (Points: 1)
#   - Gabriel dos Santos Magalhães (Points: 1)
# Midfielders:
#   - Cole Palmer (Points: 13)
#   - Kai Havertz (Points: 7)
#   - Phil Foden (Points: 2)
#   - Son Heung-min (Points: 17)
# Attackers:
#   - Jean-Philippe Mateta (Points: 8)
#   - Ollie Watkins (Points: 2)
#   - Rodrigo Muniz Carvalho (Points: 2)
# Captain: Son Heung-min (Points: 17 x2)
# Total points for Gameweek 28: 84
#
#
# --- Gameweek 29 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 0)
# Defenders:
#   - Benjamin White (Points: 0)
#   - Fabian Schär (Points: 0)
#   - Gabriel dos Santos Magalhães (Points: 0)
# Midfielders:
#   - Cole Palmer (Points: 0)
#   - Kai Havertz (Points: 0)
#   - Morgan Gibbs-White (Points: 7)
#   - Phil Foden (Points: 0)
#   - Son Heung-min (Points: 2)
# Attackers:
#   - Jean-Philippe Mateta (Points: 0)
#   - Rodrigo Muniz Carvalho (Points: 13)
# Captain: Rodrigo Muniz Carvalho (Points: 13 x2)
# Total points for Gameweek 29: 35
#
#
# --- Gameweek 30 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 2)
# Defenders:
#   - Benjamin White (Points: 6)
#   - Fabian Schär (Points: 1)
#   - Gabriel dos Santos Magalhães (Points: 6)
# Midfielders:
#   - Cole Palmer (Points: 15)
#   - Kai Havertz (Points: 3)
#   - Morgan Gibbs-White (Points: 7)
#   - Phil Foden (Points: 3)
#   - Son Heung-min (Points: 10)
# Attackers:
#   - Alexander Isak (Points: 15)
#   - Jean-Philippe Mateta (Points: 9)
# Captain: Cole Palmer (Points: 15 x2)
# Total points for Gameweek 30: 92
#
#
# --- Gameweek 31 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 3)
# Defenders:
#   - Benjamin White (Points: 6)
#   - Fabian Schär (Points: 2)
#   - Gabriel dos Santos Magalhães (Points: 6)
# Midfielders:
#   - Bruno Borges Fernandes (Points: 8)
#   - Cole Palmer (Points: 20)
#   - Kai Havertz (Points: 5)
#   - Morgan Gibbs-White (Points: 13)
#   - Phil Foden (Points: 20)
# Attackers:
#   - Alexander Isak (Points: 8)
#   - Jean-Philippe Mateta (Points: 2)
# Captain: Phil Foden (Points: 20 x2)
# Total points for Gameweek 31: 113
#
#
# --- Gameweek 32 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 8)
# Defenders:
#   - Benjamin White (Points: 5)
#   - Fabian Schär (Points: 7)
#   - Gabriel dos Santos Magalhães (Points: 6)
# Midfielders:
#   - Bruno Borges Fernandes (Points: 9)
#   - Cole Palmer (Points: 5)
#   - Kai Havertz (Points: 14)
#   - Kevin De Bruyne (Points: 18)
#   - Phil Foden (Points: 0)
# Attackers:
#   - Alexander Isak (Points: 2)
#   - Jean-Philippe Mateta (Points: 5)
# Captain: Kevin De Bruyne (Points: 18 x2)
# Total points for Gameweek 32: 97
#
#
# --- Gameweek 33 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 0)
# Defenders:
#   - Benjamin White (Points: 5)
#   - Fabian Schär (Points: 13)
#   - Joško Gvardiol (Points: 12)
# Midfielders:
#   - Bruno Borges Fernandes (Points: 15)
#   - Cole Palmer (Points: 26)
#   - Kai Havertz (Points: 1)
#   - Kevin De Bruyne (Points: 2)
#   - Phil Foden (Points: 0)
# Attackers:
#   - Alexander Isak (Points: 12)
#   - Jean-Philippe Mateta (Points: 2)
# Captain: Cole Palmer (Points: 26 x2)
# Total points for Gameweek 33: 114
#
#
# --- Gameweek 34 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 18)
# Defenders:
#   - Benjamin White (Points: 26)
#   - Jarrad Branthwaite (Points: 20)
#   - Joško Gvardiol (Points: 6)
# Midfielders:
#   - Bruno Borges Fernandes (Points: 18)
#   - Cole Palmer (Points: 0)
#   - Kai Havertz (Points: 17)
#   - Kevin De Bruyne (Points: 9)
#   - Phil Foden (Points: 16)
# Attackers:
#   - Alexander Isak (Points: 2)
#   - Jean-Philippe Mateta (Points: 29)
# Captain: Jean-Philippe Mateta (Points: 29 x2)
# Total points for Gameweek 34: 190
#
#
# --- Gameweek 35 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 10)
# Defenders:
#   - Benjamin White (Points: 1)
#   - Jarrad Branthwaite (Points: 6)
#   - Joško Gvardiol (Points: 15)
# Midfielders:
#   - Cole Palmer (Points: 8)
#   - Kai Havertz (Points: 13)
#   - Kevin De Bruyne (Points: 11)
#   - Phil Foden (Points: 0)
# Attackers:
#   - Alexander Isak (Points: 13)
#   - Erling Haaland (Points: 5)
#   - Jean-Philippe Mateta (Points: 2)
# Captain: Joško Gvardiol (Points: 15 x2)
# Total points for Gameweek 35: 99
#
#
# --- Gameweek 36 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 3)
# Defenders:
#   - Benjamin White (Points: 6)
#   - Jarrad Branthwaite (Points: 5)
#   - Joško Gvardiol (Points: 6)
# Midfielders:
#   - Cole Palmer (Points: 8)
#   - Kai Havertz (Points: 5)
#   - Michael Olise (Points: 16)
#   - Phil Foden (Points: 5)
# Attackers:
#   - Alexander Isak (Points: 7)
#   - Erling Haaland (Points: 21)
#   - Jean-Philippe Mateta (Points: 6)
# Captain: Erling Haaland (Points: 21 x2)
# Total points for Gameweek 36: 109
#
#
# --- Gameweek 37 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 8)
# Defenders:
#   - Benjamin White (Points: 6)
#   - Jarell Quansah (Points: 9)
#   - Joško Gvardiol (Points: 27)
# Midfielders:
#   - Cole Palmer (Points: 14)
#   - Kai Havertz (Points: 6)
#   - Michael Olise (Points: 12)
#   - Phil Foden (Points: 11)
# Attackers:
#   - Alexander Isak (Points: 4)
#   - Erling Haaland (Points: 15)
#   - Jean-Philippe Mateta (Points: 9)
# Captain: Joško Gvardiol (Points: 27 x2)
# Total points for Gameweek 37: 148
#
#
# --- Gameweek 38 ---
# Goalkeeper:
#   - Jordan Pickford (Points: 1)
# Defenders:
#   - Benjamin White (Points: 2)
#   - Jarell Quansah (Points: 15)
#   - Joško Gvardiol (Points: 2)
# Midfielders:
#   - Cole Palmer (Points: 6)
#   - Eberechi Eze (Points: 18)
#   - Kai Havertz (Points: 6)
#   - Michael Olise (Points: 6)
#   - Phil Foden (Points: 15)
# Attackers:
#   - Alexander Isak (Points: 14)
#   - Jean-Philippe Mateta (Points: 20)
# Captain: Jean-Philippe Mateta (Points: 20 x2)
# Total points for Gameweek 38: 125
#
#
# Total Points over all gameweeks: 3769
